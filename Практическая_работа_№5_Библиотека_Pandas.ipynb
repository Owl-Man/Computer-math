# %% [markdown]
# <a href="https://colab.research.google.com/github/Alexandre77777/computer_math/blob/main/5.%20%D0%91%D0%B8%D0%B1%D0%BB%D0%B8%D0%BE%D1%82%D0%B5%D0%BA%D0%B0%20Pandas.%20%D0%92%D0%B8%D0%B7%D1%83%D0%B0%D0%BB%D1%8C%D0%BD%D1%8B%D0%B9%20%D0%B0%D0%BD%D0%B0%D0%BB%D0%B8%D0%B7%20%D0%B4%D0%B0%D0%BD%D0%BD%D1%8B%D1%85/%D0%9F%D1%80%D0%B0%D0%BA%D1%82%D0%B8%D1%87%D0%B5%D1%81%D0%BA%D0%B0%D1%8F_%D1%80%D0%B0%D0%B1%D0%BE%D1%82%D0%B0_%E2%84%965_%D0%91%D0%B8%D0%B1%D0%BB%D0%B8%D0%BE%D1%82%D0%B5%D0%BA%D0%B0_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Практическая работа №5. Библиотека Pandas. Визуальный анализ данных

# %% [markdown]
# ## Комплексное задание №1. Применение основных методов для анализа данных
#
# 1. Скачайте этот блокнот к себе.
# 2. Заполните пропущенные ячейки, отвечая на заданные вопросы. Там должен быть код! (если не сказано обратное)
# 3. Сохраните результат в своём гитхаб репозитории.
#
# #### Полезная литература
# - [**Блокнот с теорией**](https://colab.research.google.com/drive/1SLqmaYz4xEsxVV-LGwb3ityheBTzHJQu?usp=sharing)
# - http://pandas.pydata.org/pandas-docs/stable/10min.html
# - https://pandas.pydata.org/pandas-docs/stable/indexing.html
# - https://pandas.pydata.org/pandas-docs/stable/missing_data.html

# %% [markdown]
# В этом задании мы с Вами рассмотрим датасет [Adult Data Set](https://archive.ics.uci.edu/ml/datasets/Adult).
# Основывается он на данных переписи населения 1994 года в США.
#
# Расшифровка содержимого колонок:
#
# - age: continuous.
# - workclass: Private, Self-emp-not-inc, Self-emp-inc, Federal-gov, Local-gov, State-gov, Without-pay, Never-worked.
# - fnlwgt: continuous. sampling weight, more here: SIPP Weighting.
# - education: Bachelors, Some-college, 11th, HS-grad, Prof-school, Assoc-acdm, Assoc-voc, 9th, 7th-8th, 12th, Masters, 1st-4th, 10th, Doctorate, 5th-6th, Preschool.
# - education-num: continuous.
# - marital-status: Married-civ-spouse, Divorced, Never-married, Separated, Widowed, Married-spouse-absent, Married-AF-spouse.
# - occupation: Tech-support, Craft-repair, Other-service, Sales, Exec-managerial, Prof-specialty, Handlers-cleaners, Machine-op-inspct, Adm-clerical, Farming-fishing, Transport-moving, Priv-house-serv, Protective-serv, Armed-Forces.
# - relationship: Wife, Own-child, Husband, Not-in-family, Other-relative, Unmarried.
# - race: White, Asian-Pac-Islander, Amer-Indian-Eskimo, Other, Black.
# - sex: Female, Male.
# - capital-gain: continuous. Income from investment sources, apart from wages/salary.
# - capital-loss: continuous. Losses from investment sources, apart from wages/salary.
# - hours-per-week: continuous.
# - native-country: United-States, Cambodia, England, Puerto-Rico, Canada, Germany, Outlying-US(Guam-USVI-etc), India, Japan, Greece, South, China, Cuba, Iran, Honduras, Philippines, Italy, Poland, Jamaica, Vietnam, Mexico, Portugal, Ireland, France, Dominican-Republic, Laos, Ecuador, Taiwan, Haiti, Columbia, Hungary, Guatemala, Nicaragua, Scotland, Thailand, Yugoslavia, El-Salvador, Trinadad&Tobago, Peru, Hong, Holand-Netherlands.

# %%
# %matplotlib inline
import pandas as pd
pd.__version__
# Out:
# '2.2.3'

# %% [markdown]
# Если вы увидели warning, не переживайте, всё хорошо.
# - https://stackoverflow.com/questions/40845304/runtimewarning-numpy-dtype-size-changed-may-indicate-binary-incompatibility
# - https://github.com/numpy/numpy/pull/432

# %%
columns='age,workclass,fnlwgt,education,education.num,marital.status,occupation,relationship,race,sex,capital.gain,capital.loss,hours.per.week,native.country,income'.split(',')
# df = pd.read_csv('../../data/adult.csv.gz', na_values='?') # можно загрузить из файла или URL
df = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.data', na_values=' ?', names=columns)
df.head()
# Out:
#    age          workclass  fnlwgt   education  education.num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital.status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital.gain  capital.loss  hours.per.week  native.country  income
# 0          2174             0              40   United-States   <=50K
# ...

# %% [markdown]
# 1) Выведите последние 10 элеметнов датасета

# %%
df.iloc[:10]
# Out:
#    age          workclass  fnlwgt   education  education.num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
# 5   37            Private  284582     Masters             14
# 6   49            Private  160187         9th              5
# 7   52   Self-emp-not-inc  209642     HS-grad              9
# 8   31            Private   45781     Masters             14
# 9   42            Private  159449   Bachelors             13
#
#            marital.status          occupation    relationship    race  \
# 0           Never-married        Adm-clerical   Not-in-family   White
# 1      Married-civ-spouse     Exec-managerial         Husband   White
# 2                Divorced   Handlers-cleaners   Not-in-family   White
# ...

# %% [markdown]
# 2) Сколько колонок и сколько строк в этом датасете?

# %%
columns, rows = df.shape

print(columns, rows)
# Out:
# 32561 15

# %% [markdown]
# 3) Какие типы данных у элементов этого датасета?

# %%
print(df.dtypes)
# Out:
# age                int64
# workclass         object
# fnlwgt             int64
# education         object
# education.num      int64
# marital.status    object
# occupation        object
# relationship      object
# race              object
# sex               object
# capital.gain       int64
# capital.loss       int64
# hours.per.week     int64
# native.country    object
# income            object
# dtype: object

# %% [markdown]
# 4) Какие признаки имеют пропуски?

# %%
import pandas as pd

pd.isnull(df).sum()
# Out:
# age                  0
# workclass         1836
# fnlwgt               0
# education            0
# education.num        0
# marital.status       0
# occupation        1843
# relationship         0
# race                 0
# sex                  0
# capital.gain         0
# capital.loss         0
# hours.per.week       0
# native.country     583
# income               0
# dtype: int64

# %% [markdown]
# 5) Как вы думаете, с чем связаны пропуски этих значение. Напишите развернутый ответ в ячейке ниже.

# %% [markdown]
# Ваш ответ:

# %% [markdown]
# 6) Какие и сколько различных рабочих классов workclass представлено в выборке?

# %%
print(df['workclass'].unique())
# Out:
# [' State-gov' ' Self-emp-not-inc' ' Private' ' Federal-gov' ' Local-gov'
#  nan ' Self-emp-inc' ' Without-pay' ' Never-worked']

# %% [markdown]
# 7) Какой средний возраст женщин и мужчин?

# %%
print(df['age'].mean())
# Out:
# 38.58164675532078

# %% [markdown]
# 8) Постройте гистограмму(bar) распределения образования людей (education)

# %%
df.groupby('education').count()['education.num'].plot(kind='bar')
# Out:
# <Axes: xlabel='education'>

# %% [markdown]
# 9) Каковы средние значения и среднеквадратичные отклонения возраста тех, кто получает более 50K в год (признак income) и тех, кто получает менее 50K в год?

# %%
more50k = df[df['income'] == ' >50K']['age']
less50k = df[df['income'] == ' <=50K']['age']

print(more50k.mean())
print(more50k.std())
print(less50k.mean())
print(less50k.std())
# Out:
# 44.24984058155847
# 10.519027719851826
# 36.78373786407767
# 14.02008849082488

# %% [markdown]
# 10) Правда ли, что люди, которые получают больше 50k, имеют как минимум высшее образование? (признак education - Bachelors, Prof-school, Assoc-acdm, Assoc-voc, Masters или Doctorate)

# %%
higher_education = [' Bachelors', ' Prof-school', ' Assoc-acdm', ' Assoc-voc', ' Masters', ' Doctorate']

high_income = df[df['income'] == ' >50K']

has_higher_ed = high_income['education'].isin(higher_education)
percent_higher_ed = has_higher_ed.mean() * 100
counter_examples = len(high_income) - has_higher_ed.sum()

print(f"Всего людей с доходом >50K: {len(high_income)}")
print(f"Процент с высшим образованием: {percent_higher_ed:.2f}%")
print(f"Количество людей без высшего образования: {counter_examples}")
# Out:
# Всего людей с доходом >50K: 7841
# Процент с высшим образованием: 57.84%
# Количество людей без высшего образования: 3306

# %% [markdown]
# 11) Среди кого больше доля зарабатывающих много (>50K): среди женатых или холостых мужчин (признак marital-status)? Женатыми считаем тех, у кого marital-status начинается с Married (Married-civ-spouse, Married-spouse-absent или Married-AF-spouse), остальных считаем холостыми.

# %%
men = df[df['sex'] == ' Male']

# Определяем женатых (marital.status начинается с 'Married')
married_men = men[men['marital.status'].str.startswith(' Married')]
single_men = men[~men['marital.status'].str.startswith(' Married')]

# Считаем долю с доходом >50K в каждой группе
married_high_income = married_men['income'] == ' >50K'
single_high_income = single_men['income'] == ' >50K'

married_high_income_share = married_high_income.mean() * 100
single_high_income_share = single_high_income.mean() * 100

# Выводим результаты
print(f"Женатые мужчины:")
print(f"Всего: {len(married_men)}")
print(f"Доля с доходом >50K: {married_high_income_share:.2f}%")

print(f"\nХолостые мужчины:")
print(f"Всего: {len(single_men)}")
print(f"Доля с доходом >50K: {single_high_income_share:.2f}%")
# Out:
# Женатые мужчины:
# Всего: 13541
# Доля с доходом >50K: 44.05%
#
# Холостые мужчины:
# Всего: 8249
# Доля с доходом >50K: 8.45%

# %% [markdown]
# 12) Постройте [сводную таблицу](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.pivot_table.html) для отображения зависимостей среднего времени работы (hours.per.week) с доходом (income) для каждой страны (native.country).
#
#
# > Пример фрагмента таблицы:
#
#
#
# ![image.png](data:image/png;base64,...)

# %%
pivot_table = pd.pivot_table(
    df,
    values='hours.per.week',
    index='native.country',
    columns='income',
    aggfunc='mean',
    fill_value=0
)

print(pivot_table.head(10))
# Out:
# income                  <=50K       >50K
# native.country
# Cambodia            41.416667  40.000000
# Canada              37.914634  45.641026
# China               37.381818  38.900000
# Columbia            38.684211  50.000000
# Cuba                37.985714  42.440000
# Dominican-Republic  42.338235  47.000000
# Ecuador             38.041667  48.750000
# El-Salvador         36.030928  45.000000
# England             40.483333  44.533333
# France              41.058824  50.750000

# %% [markdown]
# 13) Постройте сводную таблицу для сравнения уровня образования и разности между capital.gain и capital.loss по следующему алгоритму:&nbsp;
# 1. Создайте вспомогательную таблицу (датафрейм) и добавьте в неё столбец "education" из целевой таблицы
# 2. Добавьте во вспомогательную таблицу ещё один столбец "capital.diff", значиниями которого будут являться разности столбцов capital.gain и capital.loss целевой таблицы
# 3. Удалите во вспомогательной таблице все строки, в которых значение столбца "capital.diff" равно нулю
# &nbsp; Подсказка:
# ```
# summary_table = summary_table[summary_table['capital.diff'] != 0 ]
# ```
# 4. Для набора значений из столбца "capital.diff", необходимо сформировать 10 категорий (кластеров), это можно сделать с помощью математических функций, типа log, извлечение корня N-ой степени и округления, для последующего перехода к категориальным признакам.
#   * В нашем случае, можно воспользоваться методом [pd.qcut()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.qcut.html) и равномерно разделить наш набор данных на целевое количество категорий
# 5. Добавьте во вспомогательную таблицу столбец "categories", и проинициализируйте его значениями категорий, которые возвращает метод pd.qcut()
# &nbsp; Пример:
# ```
# summary_table['categories'] = pd.qcut(summary_table["capital.diff"], q = 10)
#
# 6. Постройте сводную таблицу с помощью метода pivot_table(),
#
# Примерная структура таблицы (в качестве значений выводится количество людей, относящихся к той или иной группе):
#
# ![image.png](data:image/png;base64,...)

# %%
import pandas as pd

summary_table = df[['education']].copy()
summary_table['capital.diff'] = df['capital.gain'] - df['capital.loss']
summary_table = summary_table[summary_table['capital.diff'] != 0]
summary_table['categories'] = pd.qcut(summary_table['capital.diff'], q=10)
pivot_result = pd.pivot_table(
    summary_table,
    index='education',
    columns='categories',
    values='capital.diff',  # Используем "capital.diff" для подсчета
    aggfunc='count',        # Подсчитываем количество записей
    fill_value=0
)

print(pivot_result)
# Out:
# categories    (-4356.001, -1977.0]  (-1977.0, -1887.0]  (-1887.0, -1594.0]  \
# education
# 10th                            11                   4                  10
# 11th                            10                   3                  14
# 12th                             1                   0                   6
# 1st-4th                          2                   0                   2
# 5th-6th                          6                   2                   2
# 7th-8th                          7                   3                   9
# 9th                              1                   0                   7
# Assoc-acdm                      14                  15                  17
# Assoc-voc                       19                  13                  12
# Bachelors                      114                 104                  60
# Doctorate                       25                  23                   2
# ...

# %% [markdown]
# 14) Женщины из каких стран получают в среднем большую зарплату (>50K) чаще.

# %%
women = df[df['sex'] == ' Female']

country_income = women.groupby('native.country').agg(
    total_women=('income', 'count'),
    high_income=('income', lambda x: (x == ' >50K').sum())
)
country_income['proportion_high_income'] = country_income['high_income'] / country_income['total_women'] * 100

country_income = country_income[country_income['total_women'] >= 10]

result = country_income.sort_values('proportion_high_income', ascending=False)

print(result[['total_women', 'high_income', 'proportion_high_income']])
# Out:
#                     total_women  high_income  proportion_high_income
# native.country
# Taiwan                       15            4               26.666667
# France                       12            3               25.000000
# Japan                        20            5               25.000000
# China                        21            5               23.809524
# Italy                        21            5               23.809524
# Canada                       39            9               23.076923
# England                      32            6               18.750000
# India                        11            2               18.181818
# Portugal                     12            2               16.666667
# Philippines                  73           12               16.438356
# Germany                      60            7               11.666667
# United-States              9682         1072               11.072093
# ...

# %% [markdown]
# 15) Создайте случайную колонку - magic_salary, которую нужно будет вычислить следующим образом: если зарплата небольшая (<50K), тогда случайно выберите число из диапазона [0,50]. Если зарплата выше 50K тогда из диапазона [51, 200]. Посчитайте среднюю зарплату в час для групп людей с одни уровнем образования на основе нашей случайной колонки magic_salary

# %%
import numpy as np
np.random.seed(42)

df['magic_salary'] = np.where(
    df['income'] == ' <=50K',
    np.random.uniform(0, 50, size=len(df)),  # Для <=50K: случайное число из [0, 50]
    np.random.uniform(51, 200, size=len(df))  # Для >50K: случайное число из [51, 200]
)

# Вычисляем зарплату в час: magic_salary (тыс. долларов в год) / (часы в неделю * 52 недели)
df['hourly_rate'] = df['magic_salary'] / (df['hours.per.week'] * 52)

hourly_by_education = df.groupby('education')['hourly_rate'].mean().sort_values(ascending=False)

print(hourly_by_education)
# Out:
# education
# Doctorate       0.050657
# Prof-school     0.044293
# Masters         0.041786
# Bachelors       0.032450
# Assoc-acdm      0.030512
# Assoc-voc       0.026672
# Some-college    0.024327
# HS-grad         0.021605
# 10th            0.021542
# 11th            0.021416
# 12th            0.020288
# 7th-8th         0.018873
# 9th             0.018049
# 5th-6th         0.016390
# 1st-4th         0.015883
# Preschool       0.014530
# Name: hourly_rate, dtype: float64

# %% [markdown]
# ## Комплексное задание №2. Визуальный анализ данных. Часть 1

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# В этом задании Вам предлагается провести визуальный анализ датасета о прокатах велосипедов https://www.kaggle.com/c/bike-sharing-demand/data. Оригинальная задача предполагает построение модели предсказания количества прокатов в городе в зависимости от погоды.

# %% [markdown]
# Для каждого дня проката известны следующие признаки (как они были указаны в источнике данных):
# - season: 1 - весна, 2 - лето, 3 - осень, 4 - зима
# - yr: 0 - 2011, 1 - 2012
# - mnth: от 1 до 12
# - holiday: 0 - нет праздника, 1 - есть праздник
# - weekday: от 0 до 6
# - workingday: 0 - нерабочий день, 1 - рабочий день
# - weathersit: оценка благоприятности погоды от 1 (чистый, ясный день) до 4 (ливень, туман)
# - temp: температура в Цельсиях
# - atemp: температура по ощущениям в Цельсиях
# - hum: влажность
# - windspeed(mph): скорость ветра в милях в час
# - windspeed(ms): скорость ветра в метрах в секунду
# - cnt: количество арендованных велосипедов (это целевой признак, его мы будем предсказывать)

# %% [markdown]
# Загрузите самостоятельно(!), с помощью pandas файл `bikes_rent.csv.gz` и выведите первые 5 строк. Ознакомьтесь с данными с помощью функций describe и info.

# %%
df = pd.read_csv('hour.csv')

df.head()
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1   0        0        6           0
# 1        2  2011-01-01       1   0     1   1        0        6           0
# 2        3  2011-01-01       1   0     1   2        0        6           0
# 3        4  2011-01-01       1   0     1   3        0        6           0
# 4        5  2011-01-01       1   0     1   4        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0           1  0.24  0.2879  0.81        0.0       3          13   16
# 1           1  0.22  0.2727  0.80        0.0       8          32   40
# 2           1  0.22  0.2727  0.80        0.0       5          27   32
# 3           1  0.24  0.2879  0.75        0.0       3          10   13
# 4           1  0.24  0.2879  0.75        0.0       0           1    1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17379 entries, 0 to 17378
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     17379 non-null  int64
#  1   dteday      17379 non-null  object
#  2   season      17379 non-null  int64
#  3   yr          17379 non-null  int64
#  4   mnth        17379 non-null  int64
#  5   hr          17379 non-null  int64
#  6   holiday     17379 non-null  int64
#  7   weekday     17379 non-null  int64
#  8   workingday  17379 non-null  int64
#  9   weathersit  17379 non-null  int64
#  10  temp        17379 non-null  float64
#  11  atemp       17379 non-null  float64
#  12  hum         17379 non-null  float64
#  13  windspeed   17379 non-null  float64
#  14  casual      17379 non-null  int64
#  15  registered  17379 non-null  int64
#  16  cnt         17379 non-null  int64
# dtypes: float64(4), int64(12), object(1)
# memory usage: 2.3+ MB

# %%
<class 'pandas.core.frame.DataFrame'>
RangeIndex: 731 entries, 0 to 730
Data columns (total 13 columns):
season            731 non-null int64
yr                731 non-null int64
mnth              731 non-null int64
holiday           731 non-null int64
weekday           731 non-null int64
workingday        731 non-null int64
weathersit        731 non-null int64
temp              731 non-null float64
atemp             731 non-null float64
hum               731 non-null float64
windspeed(mph)    731 non-null float64
windspeed(ms)     731 non-null float64
cnt               731 non-null int64
dtypes: float64(5), int64(8)
memory usage: 74.3 KB

# %% [markdown]
# Давайте посмотрим на графиках, как целевой признак зависит количество прокатов (cnt) зависит от остальных признаков `df.columns[:-1]`.

# %%
fig, axes = plt.subplots(nrows=3, ncols=4, figsize=(16, 12))
for idx, feature in enumerate(df.columns[:-1]):
     df.plot(feature, "cnt", subplots=True, kind="scatter", ax=axes[idx // 4, idx % 4])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[52], line 3
#       1 fig, axes = plt.subplots(nrows=3, ncols=4, figsize=(16, 12))
#       2 for idx, feature in enumerate(df.columns[:-1]):
# ----> 3      df.plot(feature, "cnt", subplots=True, kind="scatter", ax=axes[idx // 4, idx % 4])
#
# IndexError: index 3 is out of bounds for axis 0 with size 3

# %% [markdown]
# ### 1. Ответьте на вопросы:
#
# #### Каков характер зависимости числа прокатов от месяца?

# %% [markdown]
# ответ: на зиму и осень приходится большее число прокатов, чем на весну и лето

# %% [markdown]
# #### Укажите один или два признака, от которых число прокатов скорее всего зависит линейно
# _(чем больше значение, тем больше прокатов или наоборот, например)_
#
# Можете проверить результат с помощью lnplot.

# %% [markdown]
# Ответ: temp и/или atemp

# %% [markdown]
# ### 2. Корреляционная матрица
#
# Напомним, что корреляция отражает взаимосвязь двух случайных величин. Она бывает положительная и отрицательная. Чем ближе коэффициент корреляции к нулю, тем меньше взаимосвязь. Чем больше абсолютная корреляци, тем взаимосвязь больше.
#
# Постройте heatmap корреляционной матрицы. Матрица формируется средствами pandas, со стандартным значением параметров.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('hour.csv')

numeric_df = df.select_dtypes(include=['int64', 'float64'])

corr_matrix = numeric_df.corr()

plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Heatmap')
plt.show()

# %% [markdown]
# **Ответьте на вопрос**: с какими признаками количество прокатов коррелирует меньше всего (около 4 штуки). А с какими больше всего?

# %% [markdown]
# Ответ наименьше всего с instant, holiday, weatherset. наибольше всего с temp/atemp

# %% [markdown]
# ### 3. Barpot
#
# Постройте Bar-график суммарного количества прокатов велосипедов по месяцам за каждый год одновременно. (будет 24 столбика)

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('hour.csv')

df['dteday'] = pd.to_datetime(df['dteday'])
df['year'] = df['dteday'].dt.year
df['month'] = df['dteday'].dt.month

monthly_counts = df.groupby(['year', 'month'])['cnt'].sum().reset_index()
monthly_counts['year_month'] = monthly_counts.apply(lambda x: f"{int(x['year'])}-{int(x['month'])}", axis=1)
counts = monthly_counts['cnt']
labels = monthly_counts['year_month']

plt.figure(figsize=(12, 6))
plt.bar(labels, counts, color='skyblue')
plt.xlabel('Месяц и год')
plt.ylabel('Суммарное количество прокатов')
plt.title('Суммарное количество прокатов по месяцам за 2011 и 2012 годы')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Ответьте на вопрос:** почему в предыдущем графике была такая большая корреляция между количеством прокатов и годом?

# %% [markdown]
# Ответ: количество прокатов росло?

# %% [markdown]
# ### 4. Countplot
#
# Постройте countplot диаграммы для признаков `weekday`, `weathersit`,

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('hour.csv')

weekday_counts = df['weekday'].value_counts().sort_index()

plt.figure(figsize=(8, 5))
plt.bar(weekday_counts.index, weekday_counts.values, color='skyblue', edgecolor='black')
plt.title('Количество наблюдений по дням недели (weekday)')
plt.xlabel('День недели (0-6)')
plt.ylabel('Количество наблюдений')
plt.xticks(weekday_counts.index)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

weathersit_counts = df['weathersit'].value_counts().sort_index()

plt.figure(figsize=(8, 5))
plt.bar(weathersit_counts.index, weathersit_counts.values, color='skyblue', edgecolor='black')
plt.title('Количество наблюдений по погодным условиям (weathersit)')
plt.xlabel('Погодные условия (1-4)')
plt.ylabel('Количество наблюдений')
plt.xticks(weathersit_counts.index)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# **Ответьте на вопрос:** что вы можете сказать о том, как формировался этот датасет.

# %% [markdown]
# Ответ: каждый день в районе 2500 наблюдений. В основном наблюдения были в ясные дни

# %% [markdown]
# **Ответьте на вопрос:** как называется распределение значений признака `weekday`?

# %% [markdown]
#
# Ответ: равномерное

# %% [markdown]
# ### 5. Распределение
#
# Постройте распределение целевого признака.

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('hour.csv')

plt.figure(figsize=(10, 6))
plt.hist(df['cnt'], bins=50, color='skyblue', edgecolor='black')
plt.title('Распределение количества прокатов велосипедов (cnt)')
plt.xlabel('Количество прокатов (cnt)')
plt.ylabel('Частота')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# **Ответьте на вопрос:** основываясь на графике, сколько приблизительно в среднем прокатов бывает в день?

# %% [markdown]
# Ответ: 200-300

# %% [markdown]
# ### 6. Совместное распределение признаков
#
# Постройте график совместного распределения признаков температура и ощущение температуры.

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('hour.csv')

fig = plt.figure(figsize=(10, 8))

ax_main = fig.add_subplot(2, 2, (1, 3))
# ax_histx = fig.add_subplot(2, 2, 2)
# ax_histy = fig.add_subplot(2, 2, 4)

# Диаграмма рассеяния
ax_main.scatter(df['temp'], df['atemp'], alpha=0.5, color='skyblue', edgecolor='black')
ax_main.set_xlabel('Температура (temp)')
ax_main.set_ylabel('Ощущение температуры (atemp)')
ax_main.set_title('Совместное распределение температуры и ощущения температуры')
ax_main.grid(True, linestyle='--', alpha=0.7)

# # Гистограмма для temp
# ax_histx.hist(df['temp'], bins=30, color='skyblue', edgecolor='black')
# ax_histx.set_title('Распределение температуры (temp)')
# ax_histx.set_xlabel('Температура (temp)')
# ax_histx.set_ylabel('Частота')

# # Гистограмма для atemp
# ax_histy.hist(df['atemp'], bins=30, color='skyblue', edgecolor='black')
# ax_histy.set_title('Распределение ощущения температуры (atemp)')
# ax_histy.set_xlabel('Ощущение температуры (atemp)')
# ax_histy.set_ylabel('Частота')

# plt.tight_layout()
plt.show()

# %% [markdown]
# **Ответьте на вопрос:** вас в этом графике ничего не настораживает? Почему?

# %% [markdown]
# Ответ: только то, что есть выделяющиеся точки

# %% [markdown]
# ### 7. Боксплот (ящик с усами)
#
# Постройте график распределения (боксплот) количества прокатов велосипедов по месяцам в зависимости от того рабочий это день или нет.

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('hour.csv')

# Извлечение месяца
df['dteday'] = pd.to_datetime(df['dteday'])
df['month'] = df['dteday'].dt.month

# Разделение данных на рабочие и нерабочие дни
workingday_data = df[df['workingday'] == 1]
non_workingday_data = df[df['workingday'] == 0]

# Подготовка данных для боксплота
workingday_by_month = [workingday_data[workingday_data['month'] == month]['cnt'] for month in range(1, 13)]
non_workingday_by_month = [non_workingday_data[non_workingday_data['month'] == month]['cnt'] for month in range(1, 13)]

# Создание фигуры
plt.figure(figsize=(12, 6))

# Позиции для боксплотов
positions_working = [i - 0.2 for i in range(1, 13)]
positions_non_working = [i + 0.2 for i in range(1, 13)]

# Построение боксплотов
plt.boxplot(workingday_by_month, positions=positions_working, widths=0.4, patch_artist=True, 
            boxprops=dict(facecolor='skyblue', color='black'), 
            medianprops=dict(color='red'))
plt.boxplot(non_workingday_by_month, positions=positions_non_working, widths=0.4, patch_artist=True, 
            boxprops=dict(facecolor='lightgreen', color='black'), 
            medianprops=dict(color='red'))

# Настройка графика
plt.title('Распределение количества прокатов по месяцам (рабочие и нерабочие дни)')
plt.xlabel('Месяц')
plt.ylabel('Количество прокатов (cnt)')
plt.xticks(range(1, 13), ['Янв', 'Фев', 'Мар', 'Апр', 'Май', 'Июн', 'Июл', 'Авг', 'Сен', 'Окт', 'Ноя', 'Дек'])
plt.legend(['Рабочие дни', 'Нерабочие дни'], loc='upper left')
plt.grid(True, linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# **Ответьте на вопрос:** почему в некоторых месяцах чаще берут велосипеды в будний день, а в некоторые - в выходной.

# %% [markdown]
# Ответ:

# %% [markdown]
# ## Комплексное задание №3. Визуальный анализ данных. Часть 2

# %%
# !pip install seaborn==0.11.0
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\owl\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\owl\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\owl\appdata\local\programs\python\python310\lib\site-packages)
# ...
#   Using cached seaborn-0.11.0-py3-none-any.whl.metadata (2.2 kB)
# ...
# Using cached seaborn-0.11.0-py3-none-any.whl (283 kB)
# ...
#   Attempting uninstall: seaborn
#     Found existing installation: seaborn 0.13.2
#     Uninstalling seaborn-0.13.2:
#       Successfully uninstalled seaborn-0.13.2
# ...
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[24], line 4
#       2 import pandas as pd
#       3 import matplotlib.pyplot as plt
# ----> 4 import seaborn as sns
#
# ...

# %%
colab = False # если работаете на своём компьютере, в локальной среде, поставьте False
if colab:
    from google.colab import drive
    drive.mount('/content/drive')

# %% [markdown]
# В этом задании Вам предлагается провести визуальный анализ датасета результатов экзаменов студентов  https://www.kaggle.com/spscientist/students-performance-in-exams.

# %% [markdown]
# Исходные данные загрузите самостоятельно!

# %%
if colab:
    df = pd.read_csv('/content/drive/My Drive/Data/StudentsPerformance.csv')
else:
    df = pd.read_csv("StudentsPerformance.xls")

df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %% [markdown]
# ### Ход задания:

# %% [markdown]
# #### 1. Постройте 3 графика, показывающих распределение результатов экзаменов (каждый график на предмет).
#
#
# Графики должны быть в одном ряду и у них должен быть общий заголовок "Результаты экзаменов".
#
# Для результатов каждого экзамена посчитайте медианные значения.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("StudentsPerformance.xls")

# Создание фигуры с тремя подграфиками в одном ряду
plt.figure(figsize=(15, 5))
plt.suptitle("Результаты экзаменов", fontsize=16)

# График для математики
plt.subplot(1, 3, 1)
sns.histplot(data=df, x="math score", bins=20, color='blue')
plt.title("Математика")
plt.xlabel("Баллы")
plt.ylabel("Количество студентов")

# График для чтения
plt.subplot(1, 3, 2)
sns.histplot(data=df, x="reading score", bins=20, color='green')
plt.title("Чтение")
plt.xlabel("Баллы")
plt.ylabel("Количество студентов")

# График для письма
plt.subplot(1, 3, 3)
sns.histplot(data=df, x="writing score", bins=20, color='red')
plt.title("Письмо")
plt.xlabel("Баллы")
plt.ylabel("Количество студентов")

# Установка расстояния между общим заголовком и подграфиками
plt.tight_layout()
plt.subplots_adjust(top=0.85)

# Отображение графиков
plt.show()

# Вычисление и вывод медианных значений
median_math = df["math score"].median()
median_reading = df["reading score"].median()
median_writing = df["writing score"].median()

print(f"Медианное значение для математики: {median_math}")
print(f"Медианное значение для чтения: {median_reading}")
print(f"Медианное значение для письма: {median_writing}")
# Out:
# Медианное значение для математики: 66.0
# Медианное значение для чтения: 70.0
# Медианное значение для письма: 69.0

# %% [markdown]
# #### 2. Образование родителей
# Какие уровни образование есть в столбце *'parental level of education'* и сколько строк в датафрейме соответствует каждому уровню?
#
# Постройте график и ответьте на вопрос ниже
#
# Отличаются ли баллы по математике у детей с разным образованием родителей?
# Постройте график, где по оси Х находятся уровни образования родителей, а по У - баллы по математике.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
\
df = pd.read_csv("StudentsPerformance.xls")

# 1. Анализ уровней образования родителей
print("Уровни образования родителей и количество строк:")
parental_education_counts = df['parental level of education'].value_counts()
print(parental_education_counts)
print(f"\nОбщее количество строк: {len(df)}")

# 2. Построение графика распределения уровней образования
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='parental level of education', 
              order=parental_education_counts.index)
plt.title('Распределение уровней образования родителей')
plt.xlabel('Уровень образования')
plt.ylabel('Количество')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# 3. Анализ связи между образованием родителей и баллами по математике
plt.figure(figsize=(12, 6))
sns.boxplot(data=df, x='parental level of education', y='math score',
           order=parental_education_counts.index)
plt.title('Распределение баллов по математике в зависимости от образования родителей')
plt.xlabel('Уровень образования родителей')
plt.ylabel('Баллы по математике')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# 4. Вывод медианных значений для дополнительного анализа
median_scores = df.groupby('parental level of education')['math score'].median()
print("\nМедианные баллы по математике для каждого уровня образования:")
print(median_scores)
# Out:
# Уровни образования родителей и количество строк:
# parental level of education
# some college          226
# associate's degree    222
# high school           196
# some high school      179
# bachelor's degree     118
# master's degree        59
# Name: count, dtype: int64
#
# Общее количество строк: 1000
# Медианные баллы по математике для каждого уровня образования:
# parental level of education
# associate's degree    67.0
# bachelor's degree     68.0
# high school           63.0
# master's degree       73.0
# some college          67.5
# some high school      65.0
# Name: math score, dtype: float64

# %% [markdown]
# #### 3. Выведите число студенток, набравших больше 90 баллов по всем предметам.

# %%
import pandas as pd

# Чтение данных
df = pd.read_csv("StudentsPerformance.xls")

# Фильтрация студенток с баллами > 90 по всем предметам
female_high_scorers = df[
    (df['gender'] == 'female') & 
    (df['math score'] > 90) & 
    (df['reading score'] > 90) & 
    (df['writing score'] > 90)
]

# Подсчёт количества
count_female_high_scorers = len(female_high_scorers)

# Вывод результата
print(f"Число студенток, набравших больше 90 баллов по всем предметам: {count_female_high_scorers}")

# Дополнительно: вывод этих строк (опционально)
print("\nДанные о таких студентках:")
print(female_high_scorers)
# Out:
# Число студенток, набравших больше 90 баллов по всем предметам: 17
#
# Данные о таких студентках:
#      gender race/ethnicity parental level of education         lunch  \
# 114  female        group E           bachelor's degree      standard
# 165  female        group C           bachelor's degree      standard
# 179  female        group D            some high school      standard
# 451  female        group E                some college      standard
# 458  female        group E           bachelor's degree      standard
# 546  female        group A            some high school      standard
# 566  female        group E           bachelor's degree  free/reduced
# 594  female        group C           bachelor's degree      standard
# 685  female        group E             master's degree      standard
# 712  female        group D                some college      standard
# 717  female        group C          associate's degree      standard
# ...

# %% [markdown]
# #### 4. Сравните баллы у студентов разных полов. Используя agg() выведите минимальное, максимальное и медианное значение

# %%
import pandas as pd

df = pd.read_csv("StudentsPerformance.xls")

# Группировка по полу и агрегация баллов по предметам
comparison = df.groupby('gender')[['math score', 'reading score', 'writing score']].agg(['min', 'max', 'median'])

# Вывод результата
print("Сравнение баллов студентов разных полов:")
print(comparison)

# Дополнительно: форматированный вывод для лучшей читаемости
print("\nФорматированный вывод:")
for subject in ['math score', 'reading score', 'writing score']:
    print(f"\n{subject}:")
    for gender in comparison.index:
        print(f"{gender}: min={comparison[subject]['min'][gender]}, "
              f"max={comparison[subject]['max'][gender]}, "
              f"median={comparison[subject]['median'][gender]}")
# Out:
# Сравнение баллов студентов разных полов:
#        math score             reading score             writing score       \
#               min  max median           min  max median           min  max
# gender
# female          0  100   65.0            17  100   73.0            10  100
# male           27  100   69.0            23  100   66.0            15  100
#
#
#        median
# gender
# female   74.0
# male     64.0
#
# Форматированный вывод:
#
# math score:
# female: min=0, max=100, median=65.0
# male: min=27, max=100, median=69.0
#
# reading score:
# female: min=17, max=100, median=73.0
# male: min=23, max=100, median=66.0
#
# writing score:
# female: min=10, max=100, median=74.0
# male: min=15, max=100, median=64.0

# %% [markdown]
# #### 5. Выясните, влияет ли обед и подготовка к тесту на средний балл студентов разного пола
# ###### (подсказка: используете  [pd.agg()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.agg.html))

# %%
import pandas as pd

df = pd.read_csv("StudentsPerformance.xls")

# Добавляем столбец со средним баллом по всем предметам
df['average score'] = df[['math score', 'reading score', 'writing score']].mean(axis=1)

# Группировка по полу, типу обеда и подготовке к тесту
# Используем agg для вычисления среднего значения
result = df.groupby(['gender', 'lunch', 'test preparation course'])['average score'].agg(['mean']).reset_index()

# Переименуем столбец для ясности
result = result.rename(columns={'mean': 'average score'})

# Вывод результатов
print("Влияние обеда и подготовки к тесту на средний балл:")
print(result)

# Дополнительно: форматированный вывод
print("\nФорматированный вывод:")
for gender in ['female', 'male']:
    print(f"\n{gender.capitalize()}:")
    gender_data = result[result['gender'] == gender]
    for _, row in gender_data.iterrows():
        print(f"Обед: {row['lunch']}, Подготовка: {row['test preparation course']}, "
              f"Средний балл: {row['average score']:.2f}")

# Опционально: визуализация
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))
sns.catplot(data=df, x='lunch', y='average score', hue='test preparation course', 
            col='gender', kind='bar', height=5, aspect=1)
plt.suptitle("Влияние обеда и подготовки на средний балл по полу", y=1.05)
plt.show()
# Out:
# Влияние обеда и подготовки к тесту на средний балл:
#    gender         lunch test preparation course  average score
# 0  female  free/reduced               completed      69.528571
# 1  female  free/reduced                    none      59.501401
# 2  female      standard               completed      77.479532
# 3  female      standard                    none      70.961240
# 4    male  free/reduced               completed      65.721311
# 5    male  free/reduced                    none      58.323810
# 6    male      standard               completed      73.513274
# 7    male      standard                    none      65.486043
#
# Форматированный вывод:
#
# Female:
# Обед: free/reduced, Подготовка: completed, Средний балл: 69.53
# Обед: free/reduced, Подготовка: none, Средний балл: 59.50
# Обед: standard, Подготовка: completed, Средний балл: 77.48
# Обед: standard, Подготовка: none, Средний балл: 70.96
#
# Male:
# Обед: free/reduced, Подготовка: completed, Средний балл: 65.72
# ...

# %% [markdown]
# #### 6. Постройте график, показывающий зависимость уровня образования родителей от их расы

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv("StudentsPerformance.xls")

# Построение графика
plt.figure(figsize=(12, 6))
sns.countplot(data=df, 
              x='parental level of education', 
              hue='race/ethnicity',
              order=df['parental level of education'].value_counts().index)
plt.title('Зависимость уровня образования родителей от их расы', fontsize=14)
plt.xlabel('Уровень образования родителей', fontsize=12)
plt.ylabel('Количество', fontsize=12)
plt.xticks(rotation=45)
plt.legend(title='Раса/Этническая принадлежность')
plt.tight_layout()

# Отображение графика
plt.show()

# Дополнительно: вывод числовых данных
print("Числовая зависимость уровня образования родителей от расы:")
cross_tab = pd.crosstab(df['parental level of education'], df['race/ethnicity'])
print(cross_tab)
# Out:
# Числовая зависимость уровня образования родителей от расы:
# race/ethnicity               group A  group B  group C  group D  group E
# parental level of education
# associate's degree                14       41       78       50       39
# bachelor's degree                 12       20       40       28       18
# high school                       18       48       64       44       22
# master's degree                    3        6       19       23        8
# some college                      18       37       69       67       35
# some high school                  24       38       49       50       18

# %% [markdown]
# #### 7. Постройте график, показывающий зависимость прохождения подготовительного теста от уровня образования родителей.
#
#
# Кто чаще ходит на курсы: дети, родители которых закончили только старшую школу, или дети, чьи родители получили степень бакалавра\магистра?

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv("StudentsPerformance.xls")

# Построение графика
plt.figure(figsize=(12, 6))
sns.countplot(data=df, 
              x='parental level of education', 
              hue='test preparation course',
              order=df['parental level of education'].value_counts().index)
plt.title('Зависимость прохождения подготовительного теста от уровня образования родителей', fontsize=14)
plt.xlabel('Уровень образования родителей', fontsize=12)
plt.ylabel('Количество студентов', fontsize=12)
plt.xticks(rotation=45)
plt.legend(title='Подготовительный курс', labels=['Не пройден', 'Пройден'])
plt.tight_layout()

# Отображение графика
plt.show()

# Анализ данных для ответа на вопрос
# Фильтрация по категориям
high_school = df[df['parental level of education'].isin(['high school', 'some high school'])]
degree = df[df['parental level of education'].isin(["bachelor's degree", "master's degree"])]

# Подсчёт процента прошедших курс в каждой группе
high_school_completion_rate = (high_school['test preparation course'] == 'completed').mean() * 100
degree_completion_rate = (degree['test preparation course'] == 'completed').mean() * 100

# Вывод числовых данных
print("Процент студентов, прошедших подготовительный курс:")
print(f"Дети родителей с образованием старшей школы: {high_school_completion_rate:.2f}%")
print(f"Дети родителей со степенью бакалавра/магистра: {degree_completion_rate:.2f}%")

# Ответ на вопрос
if high_school_completion_rate > degree_completion_rate:
    print("\nДети родителей, закончивших только старшую школу, чаще ходят на курсы.")
else:
    print("\nДети родителей со степенью бакалавра/магистра чаще ходят на курсы.")
# Out:
# Процент студентов, прошедших подготовительный курс:
# Дети родителей с образованием старшей школы: 35.47%
# Дети родителей со степенью бакалавра/магистра: 37.29%
#
# Дети родителей со степенью бакалавра/магистра чаще ходят на курсы.

# %% [markdown]
# #### 8. Постройте plot.pie, показывающий, сколько людей сдали\не сдали экзамен по математике.
#
# Сдавшим считается человек, набравший 40 баллов.
#
# ###### Подсказка: создайте столбец в датафрейме, который содержит результат сдачи (сдал или не сдал)

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("StudentsPerformance.xls")

# Создание столбца с результатом сдачи экзамена
df['math_passed'] = df['math score'].apply(lambda x: 'Сдал' if x >= 40 else 'Не сдал')

# Подсчёт количества сдавших и не сдавших
pass_counts = df['math_passed'].value_counts()

# Построение круговой диаграммы
plt.figure(figsize=(8, 8))
plt.pie(pass_counts, 
        labels=pass_counts.index, 
        autopct='%1.1f%%', 
        colors=['#66b3ff', '#ff9999'],
        startangle=90)
plt.title('Результаты сдачи экзамена по математике (≥ 40 баллов)', fontsize=14)
plt.axis('equal')  # Для идеальной круглой формы
plt.show()

# Вывод числовых данных
print("Количество студентов по результатам сдачи экзамена по математике:")
print(pass_counts)
# Out:
# Количество студентов по результатам сдачи экзамена по математике:
# math_passed
# Сдал       960
# Не сдал     40
# Name: count, dtype: int64

# %% [markdown]
# #### 9. Постройте plot.pie, показывающий распределение студентов по оценкам
#
# Оценки студентов выставляются по шкале:<br>
# 0  - 40 marks : grade E<br>
# 41 - 60 marks : grade D<br>
# 60 - 70 marks : grade C<br>
# 70 - 80 marks : grade B<br>
# 80 - 90 marks : grade A<br>
# 90 - 100 marks : grade O<br>
#
# Для этого посчитайте сумму результатов за 3 экзамена и найдите среднее. Оценка выставляется по среднему значению. Если студент не сдал математику(даже если средний балл выше 40), он получает Е

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("StudentsPerformance.xls")

# Вычисление среднего балла по трём предметам
df['average_score'] = df[['math score', 'reading score', 'writing score']].mean(axis=1)

# Функция для определения оценки
def assign_grade(row):
    avg = row['average_score']
    math = row['math score']
    
    # Если математика < 40, то оценка E
    if math < 40:
        return 'E'
    # Иначе оценка по среднему баллу
    elif avg <= 40:
        return 'E'
    elif avg <= 60:
        return 'D'
    elif avg <= 70:
        return 'C'
    elif avg <= 80:
        return 'B'
    elif avg <= 90:
        return 'A'
    else:
        return 'O'

# Применение функции для создания столбца с оценками
df['grade'] = df.apply(assign_grade, axis=1)

# Подсчёт количества студентов по оценкам
grade_counts = df['grade'].value_counts().reindex(['O', 'A', 'B', 'C', 'D', 'E'], fill_value=0)

# Построение круговой диаграммы
plt.figure(figsize=(8, 8))
plt.pie(grade_counts, 
        labels=grade_counts.index, 
        autopct='%1.1f%%', 
        colors=['#ff9999', '#66b3ff', '#99ff99', '#ffcc99', '#c2c2f0', '#ffb3e6'],
        startangle=90)
plt.title('Распределение студентов по оценкам', fontsize=14)
plt.axis('equal')  # Для идеальной круглой формы
plt.show()

# Вывод числовых данных
print("Распределение студентов по оценкам:")
print(grade_counts)
# Out:
# Распределение студентов по оценкам:
# grade
# O     50
# A    144
# B    253
# C    260
# D    246
# E     47
# Name: count, dtype: int64

# %% [markdown]
# #### 10. Постройте countplot, показывающий зависимость между итоговой оценкой студентов и его полом. Студенты какого пола получили больше оценок О, А, В

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv("StudentsPerformance.xls")

# Вычисление среднего балла
df['average_score'] = df[['math score', 'reading score', 'writing score']].mean(axis=1)

# Функция для определения оценки
def assign_grade(row):
    avg = row['average_score']
    math = row['math score']
    if math < 40:  # Не сдал математику
        return 'E'
    elif avg <= 40:
        return 'E'
    elif avg <= 60:
        return 'D'
    elif avg <= 70:
        return 'C'
    elif avg <= 80:
        return 'B'
    elif avg <= 90:
        return 'A'
    else:
        return 'O'

# Применение функции для создания столбца с оценками
df['grade'] = df.apply(assign_grade, axis=1)

# Построение графика
plt.figure(figsize=(10, 6))
sns.countplot(data=df, 
              x='grade', 
              hue='gender',
              order=['O', 'A', 'B', 'C', 'D', 'E'])
plt.title('Зависимость итоговой оценки от пола студентов', fontsize=14)
plt.xlabel('Итоговая оценка', fontsize=12)
plt.ylabel('Количество студентов', fontsize=12)
plt.legend(title='Пол', labels=['Женщины', 'Мужчины'])
plt.tight_layout()
plt.show()

# Анализ данных для ответа на вопрос
grade_gender_counts = pd.crosstab(df['grade'], df['gender'])
print("Распределение оценок по полу:")
print(grade_gender_counts)

# Подсчёт для O, A, B
for grade in ['O', 'A', 'B']:
    female_count = grade_gender_counts.loc[grade, 'female']
    male_count = grade_gender_counts.loc[grade, 'male']
    print(f"\nОценка {grade}:")
    print(f"Женщины: {female_count}")
    print(f"Мужчины: {male_count}")
    if female_count > male_count:
        print(f"Женщины получили больше оценок {grade}")
    elif male_count > female_count:
        print(f"Мужчины получили больше оценок {grade}")
    else:
        print(f"Одинаковое количество мужчин и женщин получили оценку {grade}")
# Out:
# Распределение оценок по полу:
# gender  female  male
# grade
# A           79    65
# B          148   105
# C          127   133
# D           97   149
# E           31    16
# O           36    14
#
# Оценка O:
# Женщины: 36
# Мужчины: 14
# Женщины получили больше оценок O
#
# Оценка A:
# Женщины: 79
# Мужчины: 65
# Женщины получили больше оценок A
#
# Оценка B:
# Женщины: 148
# Мужчины: 105
# Женщины получили больше оценок B
